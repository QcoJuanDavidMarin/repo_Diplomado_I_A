# %% [markdown]
# <a href="https://colab.research.google.com/github/QcoJuanDavidMarin/repo_Diplomado_I_A/blob/main/Untitled13_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Autoencoders: Ejemplo LFW
#
# [Aumentar resolución](https://medium.com/analytics-vidhya/super-resolution-using-autoencoders-and-tf2-0-505215c1674)

# %%
import cv2
#importar pandas para manejo de dataframes
import pandas as pd
# import tarfile para manejo de archivos comprimidos
import tarfile
# Barra de progreso
from tqdm.notebook import tqdm
# Manejo de archivos del computador
import os
# Manejo de gráficos
import matplotlib.pyplot as plt
# Manejo de Arreglos
import numpy as np

# %% [markdown]
# ##  Descargar los datos

# %%
# !wget --no-check-certificate \
  http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz \
  -O /tmp/lfw-deepfunneled.tgz

# !wget --no-check-certificate \
  http://www.cs.columbia.edu/CAVE/databases/pubfig/download/lfw_attributes.txt \
  -O /tmp/lfw_attributes.txt

# !wget --no-check-certificate \
  http://vis-www.cs.umass.edu/lfw/lfw.tgz \
  -O /tmp/lfw.tgz
# Out:
# --2021-05-11 14:24:44--  http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 108761145 (104M) [application/x-gzip]
# Saving to: ‘/tmp/lfw-deepfunneled.tgz’
#
# /tmp/lfw-deepfunnel 100%[===================>] 103.72M  33.1MB/s    in 3.3s
#
# 2021-05-11 14:24:47 (31.6 MB/s) - ‘/tmp/lfw-deepfunneled.tgz’ saved [108761145/108761145]
#
# --2021-05-11 14:24:47--  http://www.cs.columbia.edu/CAVE/databases/pubfig/download/lfw_attributes.txt
# Resolving www.cs.columbia.edu (www.cs.columbia.edu)... 128.59.11.206
# Connecting to www.cs.columbia.edu (www.cs.columbia.edu)|128.59.11.206|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.cs.columbia.edu/CAVE/databases/pubfig/download/lfw_attributes.txt [following]
# --2021-05-11 14:24:48--  https://www.cs.columbia.edu/CAVE/databases/pubfig/download/lfw_attributes.txt
# Connecting to www.cs.columbia.edu (www.cs.columbia.edu)|128.59.11.206|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14879205 (14M) [text/plain]
# Saving to: ‘/tmp/lfw_attributes.txt’
#
# /tmp/lfw_attributes 100%[===================>]  14.19M  20.1MB/s    in 0.7s
#
# 2021-05-11 14:24:49 (20.1 MB/s) - ‘/tmp/lfw_attributes.txt’ saved [14879205/14879205]
#
# --2021-05-11 14:24:49--  http://vis-www.cs.umass.edu/lfw/lfw.tgz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180566744 (172M) [application/x-gzip]
# Saving to: ‘/tmp/lfw.tgz’
#
# /tmp/lfw.tgz        100%[===================>] 172.20M  37.8MB/s    in 5.0s
#
# 2021-05-11 14:24:54 (34.1 MB/s) - ‘/tmp/lfw.tgz’ saved [180566744/180566744]

# %%
import os 
import zipfile

# %%
ATTRS_NAME = '/tmp/lfw_attributes.txt'
IMAGES_NAME = '/tmp/lfw-deepfunneled.tgz'
RAW_IMAGES_NAME = '/tmp/lfw.tgz'

# %% [markdown]
# ## Funciones para leer y preprocesar los datos usando OpenCV

# %%
## Función  para decodificar las imágenes bajadas desde datos crudos (bytes)
def decode_image_from_raw_bytes(raw_bytes):
    # Decodificar desde archivos crudos en formato adecuado, flag =1 significa leer en BGR
    img = cv2.imdecode(np.asarray(bytearray(raw_bytes), dtype=np.uint8), 1)
    #Convertir a RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img

# %% [markdown]
# ## Procesamiento individual

# %%
indice=2
with tarfile.open(RAW_IMAGES_NAME) as f:
    m=f.getmembers()[indice]
    print(m)
    img=decode_image_from_raw_bytes(f.extractfile(m).read())
    print(img.shape)
# Out:
# <TarInfo 'lfw/George_HW_Bush/George_HW_Bush_0001.jpg' at 0x7fe6c5bafae0>
# (250, 250, 3)

# %%
with tarfile.open(RAW_IMAGES_NAME) as f:
  m=f.getmembers()[indice]
  raw_bytes=f.extractfile(m).read()
  print(bytearray(raw_bytes)[:10])
# Out:
# bytearray(b'\xff\xd8\xff\xe0\x00\x10JFIF')

# %%
plt.figure(figsize=(12,5))
plt.subplot(131)
plt.imshow(img)

dx=32
dy=32
img_new=img[dx:-dx,dy:-dy]
plt.subplot(132)
plt.imshow(img_new)

dimx=45
dimy=45

img_new = cv2.resize(img_new, (dimx, dimy))
plt.subplot(133)
plt.imshow(img_new)

plt.show()

# %%
## Función para bajar las imagenes del .tgz y preprocesarlas sistemáticamente
def load_lfw_dataset(
        use_raw=False,
        dx=80, dy=80,
        dimx=45, dimy=45):

    # Leer archivo lfw_attributes.txt y hacer una limpieza inicial
    df_attrs = pd.read_csv(ATTRS_NAME, sep='\t', skiprows=1)
    # Corrimiento de carácteres incorrectos
    df_attrs = pd.DataFrame(df_attrs.iloc[:, :-1].values, columns=df_attrs.columns[1:])
    # Filtrar nombres de personas y numeros de imagen (por persona), convertir a conjunto
    imgs_with_attrs = set(map(tuple, df_attrs[["person", "imagenum"]].values))

    # Leer Fotos e identificación
    all_photos = []
    photo_ids = []

    # Abrir archivo .tgz sin descomprimir
    with tarfile.open(RAW_IMAGES_NAME if use_raw else IMAGES_NAME) as f:
        # tqdm se usa para mostrar la barra de progreso
        for m in tqdm(f.getmembers()):
            # Solo procesa los archivos desde el archivo comprimido que sean realmente imágenes (.jpg)
            if m.isfile() and m.name.endswith(".jpg"):
                # Descomprimir archivo desde el comprimido y convertir a RGB
                img = decode_image_from_raw_bytes(f.extractfile(m).read())

                # Recortar lo que sean caras y cambiar tamaño
                img = img[dy:-dy, dx:-dx]
                img = cv2.resize(img, (dimx, dimy))

                # Obtener nombre de la persona y agregarlo a la colección de datos
                fname = os.path.split(m.name)[-1]
                # La razón de -4 es para quitar la extensión .jpg
                fname_splitted = fname[:-4].replace('_', ' ').split()
                # Sacar la identificación del nombre
                person_id = ' '.join(fname_splitted[:-1])
                # Sacar el número de foto por separado
                photo_number = int(fname_splitted[-1])
                # Comparar los metadatos con las fotos reales (DEBEN COINCIDIR)
                if (person_id, photo_number) in imgs_with_attrs:
                    # Cuando coinciden, agregar las fotos
                    all_photos.append(img)
                    # Y también agregar la identidad de las personas
                    photo_ids.append({'person': person_id, 'imagenum': photo_number})
                    
    # Hacer un dataframe con los resultados
    photo_ids = pd.DataFrame(photo_ids)
    # UNir las imágenes en un tensor 4D
    all_photos = np.stack(all_photos).astype('uint8')

    # Preservar el orden de encontrados en búsqueda
    all_attrs = photo_ids.merge(df_attrs, on=('person', 'imagenum')).drop(["person", "imagenum"], axis=1)

    return all_photos, all_attrs, photo_ids

# %%
# Obtener el conjunto de datos sin descomprimir
dim_x=65
dim_y=65
X, attr,names = load_lfw_dataset(use_raw=True, dimx=dim_x, dimy=dim_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3464f609a94a> in <module>()
#       2 dim_x=120
#       3 dim_y=120
# ----> 4 X, attr,names = load_lfw_dataset(use_raw=True, dimx=dim_x, dimy=dim_y)
#
# <ipython-input-3-c6318ad3f713> in load_lfw_dataset(use_raw, dx, dy, dimx, dimy)
#       6
#       7     # Leer archivo lfw_attributes.txt y hacer una limpieza inicial
# ----> 8     df_attrs = pd.read_csv(ATTRS_NAME, sep='\t', skiprows=1)
#       9     # Corrimiento de carácteres incorrectos
#      10     df_attrs = pd.DataFrame(df_attrs.iloc[:, :-1].values, columns=df_attrs.columns[1:])
#
# NameError: name 'pd' is not defined

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bc5f1a0adac8> in <module>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
attr.shape
# Out:
# (13143, 73)

# %%
names.shape
# Out:
# (13143, 2)

# %%
azar = np.random.randint(len(X))
plt.figure(figsize=(5,5))
plt.imshow(X[azar])
plt.xticks([])
plt.yticks([])
plt.xlabel(names.person[azar])
plt.show()

# %%
plt.figure(figsize=(12,10))
numero_muestras = 30

muestras=np.random.randint(0,len(X), numero_muestras)

for i in range(numero_muestras):
  plt.subplot(5,6,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(X[muestras[i]])
  plt.xlabel(names.person[muestras[i]])
plt.show()

# %% [markdown]
# ## Normalizar los datos

# %%
X = X.astype('float32')/255.
X.shape
# Out:
# (13143, 64, 64, 3)

# %% [markdown]
# ## Convertir imagenes a escala de grises

# %%
X_gray = X[..., :3]@[0.299,0.587,0.114]
print(X_gray.shape)
# Out:
# (13143, 64, 64)

# %%
plt.figure(figsize=(12,10))
numero_muestras = 30

muestras=np.random.randint(0,len(X_gray), numero_muestras)

for i in range(numero_muestras):
  plt.subplot(5,6,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(X_gray[muestras[i]], cmap='gray')
  plt.xlabel(names.person[muestras[i]])
plt.show()

# %%
# Agregar dimensión para la entrada
X_gray = np.expand_dims(X_gray, axis=3)
print(X_gray.shape)
# Out:
# (13143, 64, 64, 1)

# %% [markdown]
# ## Importar módulos

# %%
# Importar tensorflow
import tensorflow as tf 
# importar layers apropiados para la Red
from tensorflow.keras.layers import Input, Dense, Activation, Flatten, Reshape, Conv2D, Conv2DTranspose # Para realizar deconvolución 
from tensorflow.keras.models import Model
# Graficar modelo
from tensorflow.keras.utils import plot_model
# Importar optimizadores
from tensorflow.keras.optimizers import Adam, Adamax
# Importar Función de Pérdida
from tensorflow.keras.losses import MeanSquaredError
# Función parar separar datos de entrenamiento y validación
from sklearn.model_selection import train_test_split
# Callbacks
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# ## Parámetros de la red Codificadora

# %%
 print(X_gray.shape)
 print(X.shape)
# Out:
# (13143, 64, 64, 1)
# (13143, 64, 64, 3)

# %%
# Van a entrar x_train.shape[1] filas, x_train.shape[2] columnas y x_train.shape[3] canales de color
rows = X.shape[1]
cols =  X.shape[2]
channels = X.shape[3]

input_shape = (rows, cols, 1)
batch_size = 256
kernel_size = 2
latent_dim = 1024
epochs = 50

layer_filters = [16,128,256,1024]

# %% [markdown]
# ## Codificador: encoder

# %%
inputs = Input(shape=input_shape)
x = inputs 
for filters in layer_filters:
  x = Conv2D(filters=filters,
             kernel_size= kernel_size,
             strides = 2,
             activation = 'relu',
             padding = 'same')(x)
# Guardar la forma del decoder
shape = x.shape.as_list()

x = Flatten()(x)
latent = Dense(latent_dim, name = 'Latenet_Vector')(x)
encoder_colorizing = Model(inputs, latent, name = 'Encoder_Colorizing')

# %%
encoder_colorizing.summary()
plot_model(encoder_colorizing, show_shapes=True)
# Out:
# Model: "Encoder_Colorizing"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 16)        80
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       8320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         131328
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 1024)        1049600
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# Latenet_Vector (Dense)       (None, 1024)              16778240
# =================================================================
# Total params: 17,967,568
# Trainable params: 17,967,568
# Non-trainable params: 0
# _________________________________________________________________

# %%
(shape[1]*shape[2]*shape[3])
shape[3]
latent_dim
channels
# Out:
# 3

# %% [markdown]
# # Decodificador: decoder

# %%
latent_inputs = Input(shape= (latent_dim,), name = 'decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1],shape[2],shape[3]))(x)
#Deconvolución  
for filters in layer_filters[::-1]:
  x = Conv2DTranspose(filters=filters,
                      kernel_size = kernel_size,
                      strides = 2,
                      activation = 'relu',
                      padding = 'same')(x)

outputs = Conv2DTranspose(filters=channels,
                          kernel_size=2,
                          activation = 'sigmoid',
                          padding = 'same',
                          
                          name =  'decoder_output')(x)

decoder_colorizing = Model(latent_inputs, outputs, name = 'decoder_colorizing')

# %%
decoder_colorizing.summary()
plot_model(decoder_colorizing, show_shapes=True)
# Out:
# Model: "decoder_colorizing"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 1024)]            0
# _________________________________________________________________
# dense (Dense)                (None, 16384)             16793600
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 1024)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 1024)        4195328
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 256)       1048832
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 128)       131200
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 64, 16)        8208
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 64, 64, 3)         195
# =================================================================
# Total params: 22,177,363
# Trainable params: 22,177,363
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Auto-codificador: auto-encoder

# %%
autoencder_colorizing = Model(inputs, decoder_colorizing(encoder_colorizing(inputs)),
                              name = 'autoencoder_colorizing')

# %%
autoencder_colorizing.summary()
plot_model(autoencder_colorizing,show_shapes=True)
# Out:
# Model: "autoencoder_colorizing"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# Encoder_Colorizing (Function (None, 1024)              17967568
# _________________________________________________________________
# decoder_colorizing (Function (None, 64, 64, 3)         22177363
# =================================================================
# Total params: 40,144,931
# Trainable params: 40,144,931
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Callbacks

# %%
# preparar el directorio de guardado del modelo.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'Colorized_ae_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
# reducir la tasa de aprendizaje en sqrt (0.1) si la pérdida no mejora en 5 épocas
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0, patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

# Guardar los pesos para usos futuros (p.ej. recargar parámetros sin entrenamiento)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

# Llamar cada epoch
callbacks = [lr_reducer, checkpoint]

# %% [markdown]
# # Compilar

# %%
autoencder_colorizing.compile(loss='mse',
                               optimizer = 'adam',
                               metrics = ['mae'])

# %%
# Separar datos en entrenamiento y validación interna 
X_train,X_test=train_test_split(X,test_size=0.1, random_state=42)

# %%
# Separar datos en entrenamiento y validación interna para imagenes a B/N
X_train_gray,X_test_gray=train_test_split(X_gray,test_size=0.1, random_state=42)

# %% [markdown]
# ## Entrenar el modelo

# %%
history = autoencder_colorizing.fit(X_gray, X,
                                    validation_data=(X_test_gray, X_test),
                                    epochs =epochs,
                                    batch_size = batch_size,
                                    callbacks= callbacks)
# Out:
# Epoch 1/50
# 52/52 [==============================] - 47s 231ms/step - loss: 0.0413 - mae: 0.1649 - val_loss: 0.0303 - val_mae: 0.1381
#
# Epoch 00001: val_loss improved from inf to 0.03028, saving model to /content/saved_models/Colorized_ae_model.001.h5
# Epoch 2/50
# 52/52 [==============================] - 11s 202ms/step - loss: 0.0299 - mae: 0.1363 - val_loss: 0.0168 - val_mae: 0.0985
#
# Epoch 00002: val_loss improved from 0.03028 to 0.01680, saving model to /content/saved_models/Colorized_ae_model.002.h5
# Epoch 3/50
# 52/52 [==============================] - 11s 205ms/step - loss: 0.0155 - mae: 0.0939 - val_loss: 0.0123 - val_mae: 0.0833
#
# Epoch 00003: val_loss improved from 0.01680 to 0.01232, saving model to /content/saved_models/Colorized_ae_model.003.h5
# Epoch 4/50
# 52/52 [==============================] - 11s 207ms/step - loss: 0.0121 - mae: 0.0824 - val_loss: 0.0101 - val_mae: 0.0750
#
# Epoch 00004: val_loss improved from 0.01232 to 0.01011, saving model to /content/saved_models/Colorized_ae_model.004.h5
# Epoch 5/50
# 52/52 [==============================] - 11s 210ms/step - loss: 0.0098 - mae: 0.0737 - val_loss: 0.0090 - val_mae: 0.0719
#
# Epoch 00005: val_loss improved from 0.01011 to 0.00901, saving model to /content/saved_models/Colorized_ae_model.005.h5
# Epoch 6/50
# 52/52 [==============================] - 11s 212ms/step - loss: 0.0084 - mae: 0.0680 - val_loss: 0.0079 - val_mae: 0.0666
#
# Epoch 00006: val_loss improved from 0.00901 to 0.00791, saving model to /content/saved_models/Colorized_ae_model.006.h5
# Epoch 7/50
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0076 - mae: 0.0647 - val_loss: 0.0070 - val_mae: 0.0617
#
# Epoch 00007: val_loss improved from 0.00791 to 0.00697, saving model to /content/saved_models/Colorized_ae_model.007.h5
# Epoch 8/50
# 52/52 [==============================] - 11s 216ms/step - loss: 0.0068 - mae: 0.0609 - val_loss: 0.0064 - val_mae: 0.0595
#
# Epoch 00008: val_loss improved from 0.00697 to 0.00644, saving model to /content/saved_models/Colorized_ae_model.008.h5
# Epoch 9/50
# 52/52 [==============================] - 11s 218ms/step - loss: 0.0061 - mae: 0.0579 - val_loss: 0.0056 - val_mae: 0.0555
#
# Epoch 00009: val_loss improved from 0.00644 to 0.00563, saving model to /content/saved_models/Colorized_ae_model.009.h5
# Epoch 10/50
# 52/52 [==============================] - 11s 221ms/step - loss: 0.0056 - mae: 0.0553 - val_loss: 0.0053 - val_mae: 0.0535
#
# Epoch 00010: val_loss improved from 0.00563 to 0.00527, saving model to /content/saved_models/Colorized_ae_model.010.h5
# Epoch 11/50
# 52/52 [==============================] - 12s 222ms/step - loss: 0.0053 - mae: 0.0537 - val_loss: 0.0048 - val_mae: 0.0511
#
# Epoch 00011: val_loss improved from 0.00527 to 0.00482, saving model to /content/saved_models/Colorized_ae_model.011.h5
# Epoch 12/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0049 - mae: 0.0516 - val_loss: 0.0045 - val_mae: 0.0496
#
# Epoch 00012: val_loss improved from 0.00482 to 0.00454, saving model to /content/saved_models/Colorized_ae_model.012.h5
# Epoch 13/50
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0045 - mae: 0.0497 - val_loss: 0.0043 - val_mae: 0.0485
#
# Epoch 00013: val_loss improved from 0.00454 to 0.00432, saving model to /content/saved_models/Colorized_ae_model.013.h5
# Epoch 14/50
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0043 - mae: 0.0486 - val_loss: 0.0043 - val_mae: 0.0487
#
# Epoch 00014: val_loss improved from 0.00432 to 0.00432, saving model to /content/saved_models/Colorized_ae_model.014.h5
# Epoch 15/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0042 - mae: 0.0476 - val_loss: 0.0042 - val_mae: 0.0479
#
# Epoch 00015: val_loss improved from 0.00432 to 0.00416, saving model to /content/saved_models/Colorized_ae_model.015.h5
# Epoch 16/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0040 - mae: 0.0468 - val_loss: 0.0038 - val_mae: 0.0457
#
# Epoch 00016: val_loss improved from 0.00416 to 0.00383, saving model to /content/saved_models/Colorized_ae_model.016.h5
# Epoch 17/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0039 - mae: 0.0464 - val_loss: 0.0041 - val_mae: 0.0476
#
# Epoch 00017: val_loss did not improve from 0.00383
# Epoch 18/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0040 - mae: 0.0468 - val_loss: 0.0036 - val_mae: 0.0444
#
# Epoch 00018: val_loss improved from 0.00383 to 0.00361, saving model to /content/saved_models/Colorized_ae_model.018.h5
# Epoch 19/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0036 - mae: 0.0445 - val_loss: 0.0035 - val_mae: 0.0440
#
# Epoch 00019: val_loss improved from 0.00361 to 0.00355, saving model to /content/saved_models/Colorized_ae_model.019.h5
# Epoch 20/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0035 - mae: 0.0439 - val_loss: 0.0035 - val_mae: 0.0436
#
# Epoch 00020: val_loss improved from 0.00355 to 0.00346, saving model to /content/saved_models/Colorized_ae_model.020.h5
# Epoch 21/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0035 - mae: 0.0438 - val_loss: 0.0034 - val_mae: 0.0428
#
# Epoch 00021: val_loss improved from 0.00346 to 0.00335, saving model to /content/saved_models/Colorized_ae_model.021.h5
# Epoch 22/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0033 - mae: 0.0428 - val_loss: 0.0036 - val_mae: 0.0449
#
# Epoch 00022: val_loss did not improve from 0.00335
# Epoch 23/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0034 - mae: 0.0434 - val_loss: 0.0031 - val_mae: 0.0413
#
# Epoch 00023: val_loss improved from 0.00335 to 0.00312, saving model to /content/saved_models/Colorized_ae_model.023.h5
# Epoch 24/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0031 - val_mae: 0.0416
#
# Epoch 00024: val_loss improved from 0.00312 to 0.00311, saving model to /content/saved_models/Colorized_ae_model.024.h5
# Epoch 25/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0031 - mae: 0.0413 - val_loss: 0.0030 - val_mae: 0.0410
#
# Epoch 00025: val_loss improved from 0.00311 to 0.00302, saving model to /content/saved_models/Colorized_ae_model.025.h5
# Epoch 26/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0028 - val_mae: 0.0396
#
# Epoch 00026: val_loss improved from 0.00302 to 0.00283, saving model to /content/saved_models/Colorized_ae_model.026.h5
# Epoch 27/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0029 - mae: 0.0399 - val_loss: 0.0029 - val_mae: 0.0403
#
# Epoch 00027: val_loss did not improve from 0.00283
# Epoch 28/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0028 - mae: 0.0397 - val_loss: 0.0027 - val_mae: 0.0390
#
# Epoch 00028: val_loss improved from 0.00283 to 0.00273, saving model to /content/saved_models/Colorized_ae_model.028.h5
# Epoch 29/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0027 - mae: 0.0388 - val_loss: 0.0025 - val_mae: 0.0377
#
# Epoch 00029: val_loss improved from 0.00273 to 0.00254, saving model to /content/saved_models/Colorized_ae_model.029.h5
# Epoch 30/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0026 - mae: 0.0383 - val_loss: 0.0024 - val_mae: 0.0367
#
# Epoch 00030: val_loss improved from 0.00254 to 0.00241, saving model to /content/saved_models/Colorized_ae_model.030.h5
# Epoch 31/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0024 - mae: 0.0369 - val_loss: 0.0026 - val_mae: 0.0383
#
# Epoch 00031: val_loss did not improve from 0.00241
# Epoch 32/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0022 - val_mae: 0.0355
#
# Epoch 00032: val_loss improved from 0.00241 to 0.00224, saving model to /content/saved_models/Colorized_ae_model.032.h5
# Epoch 33/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0023 - mae: 0.0360 - val_loss: 0.0021 - val_mae: 0.0342
#
# Epoch 00033: val_loss improved from 0.00224 to 0.00209, saving model to /content/saved_models/Colorized_ae_model.033.h5
# Epoch 34/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0021 - mae: 0.0347 - val_loss: 0.0021 - val_mae: 0.0349
#
# Epoch 00034: val_loss did not improve from 0.00209
# Epoch 35/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0021 - mae: 0.0347 - val_loss: 0.0023 - val_mae: 0.0362
#
# Epoch 00035: val_loss did not improve from 0.00209
# Epoch 36/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0021 - mae: 0.0348 - val_loss: 0.0021 - val_mae: 0.0343
#
# Epoch 00036: val_loss improved from 0.00209 to 0.00207, saving model to /content/saved_models/Colorized_ae_model.036.h5
# Epoch 37/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0020 - mae: 0.0336 - val_loss: 0.0020 - val_mae: 0.0332
#
# Epoch 00037: val_loss improved from 0.00207 to 0.00195, saving model to /content/saved_models/Colorized_ae_model.037.h5
# Epoch 38/50
# 52/52 [==============================] - 12s 228ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 0.0020 - val_mae: 0.0338
#
# Epoch 00038: val_loss did not improve from 0.00195
# Epoch 39/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 0.0017 - val_mae: 0.0307
#
# Epoch 00039: val_loss improved from 0.00195 to 0.00169, saving model to /content/saved_models/Colorized_ae_model.039.h5
# Epoch 40/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0017 - mae: 0.0310 - val_loss: 0.0017 - val_mae: 0.0310
#
# Epoch 00040: val_loss did not improve from 0.00169
# Epoch 41/50
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0017 - mae: 0.0306 - val_loss: 0.0016 - val_mae: 0.0299
#
# Epoch 00041: val_loss improved from 0.00169 to 0.00159, saving model to /content/saved_models/Colorized_ae_model.041.h5
# Epoch 42/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0016 - mae: 0.0304 - val_loss: 0.0015 - val_mae: 0.0287
#
# Epoch 00042: val_loss improved from 0.00159 to 0.00148, saving model to /content/saved_models/Colorized_ae_model.042.h5
# Epoch 43/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0015 - mae: 0.0292 - val_loss: 0.0014 - val_mae: 0.0284
#
# Epoch 00043: val_loss improved from 0.00148 to 0.00145, saving model to /content/saved_models/Colorized_ae_model.043.h5
# Epoch 44/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0015 - mae: 0.0288 - val_loss: 0.0014 - val_mae: 0.0282
#
# Epoch 00044: val_loss improved from 0.00145 to 0.00142, saving model to /content/saved_models/Colorized_ae_model.044.h5
# Epoch 45/50
# 52/52 [==============================] - 12s 225ms/step - loss: 0.0014 - mae: 0.0284 - val_loss: 0.0014 - val_mae: 0.0283
#
# Epoch 00045: val_loss did not improve from 0.00142
# Epoch 46/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0015 - mae: 0.0294 - val_loss: 0.0014 - val_mae: 0.0280
#
# Epoch 00046: val_loss improved from 0.00142 to 0.00140, saving model to /content/saved_models/Colorized_ae_model.046.h5
# Epoch 47/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0014 - mae: 0.0283 - val_loss: 0.0013 - val_mae: 0.0275
#
# Epoch 00047: val_loss improved from 0.00140 to 0.00135, saving model to /content/saved_models/Colorized_ae_model.047.h5
# Epoch 48/50
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0014 - val_mae: 0.0281
#
# Epoch 00048: val_loss did not improve from 0.00135
# Epoch 49/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0013 - mae: 0.0273 - val_loss: 0.0013 - val_mae: 0.0267
#
# Epoch 00049: val_loss improved from 0.00135 to 0.00127, saving model to /content/saved_models/Colorized_ae_model.049.h5
# Epoch 50/50
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0012 - mae: 0.0262 - val_loss: 0.0013 - val_mae: 0.0269
#
# Epoch 00050: val_loss did not improve from 0.00127

# %%
plt.figure(figsize=(15,7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.show()

# %% [markdown]
# # Predicciones y gráficas

# %%
x_decoded = autoencder_colorizing.predict(X_gray)

# %% [markdown]
# # Imágenes coloreadas con la predicción

# %%
plt.figure(figsize = (12,10))
numero_muestras = 30
muestras = np.random.randint(0, len(x_decoded), numero_muestras)

for i in range(numero_muestras):
  plt.subplot(5,6,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x_decoded[muestras[i]])
  plt.xlabel(names.person[muestras[i]])
plt.show()

# %%
print(X.shape)
print(X_gray.shape)
# Out:
# (13143, 64, 64, 3)
# (13143, 64, 64, 1)

# %%
plt.figure(figsize=(23,23))

img_rows = rows
img_cols = cols 

# Imagenes reales
plt.subplot(131)
imgs_t = X[:100]
imgs_t = imgs_t.reshape((10,10, img_rows, img_cols, channels))
imgs_t = np.vstack([np.hstack(i) for i in imgs_t])
#plt.figure(figsize=(10,10))
plt.axis('off')
plt.title('True color images')
plt.imshow(imgs_t, interpolation='none')

# Imagenes PREDICHAS
 
plt.subplot(132)
imgs = x_decoded[:100]
imgs = imgs.reshape((10,10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
#plt.figure(figsize=(10,10))
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')


# Imagenes a B/N 
plt.subplot(133)

imgs_g = X_gray[:100]
imgs_g = imgs_g.reshape((10,10, img_rows, img_cols))
imgs_g = np.vstack([np.hstack(i) for i in imgs_g])
#plt.figure(figsize=(10,10))
plt.axis('off')
plt.title('Test gray images (Input)')
plt.imshow(imgs_g, interpolation='none', cmap='gray')

plt.show()

# %% [markdown]
# # PREDICCIÓN CON UNA FOTO

# %%
import cv2
from PIL import Image

# %%
from google.colab import files
imagesbn = files.upload()
# Out:
#      <input type="file" id="files-0d4af474-df62-4153-9c4e-41dd3ff7ee56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d4af474-df62-4153-9c4e-41dd3ff7ee56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
mi_foto_gris = Image.open('/content/jjjj.jpg')
mi_foto_gris = mi_foto_gris.convert('L')

# %%
plt.figure(figsize=(5,5))
plt.title('Imagen Original', fontsize = 15)
plt.imshow(mi_foto_gris, cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# # Normalizar el la imagen de entrada

# %%
mi_foto_gris_norm = (np.array(mi_foto_gris))/255. 

print('La forma fde la imagen reducida es:', mi_foto_gris_norm.shape)
mi_foto_gris_norm = cv2.resize(mi_foto_gris_norm,(64,64)).flatten()
print('Data flatten',mi_foto_gris_norm.shape)
mi_foto_gris_norm = np.array(mi_foto_gris_norm).reshape(1,64,64,1)

print('Nueva forma de los datos:', mi_foto_gris_norm.shape)
# Out:
# La forma fde la imagen reducida es: (525, 350)
# Data flatten (4096,)
# Nueva forma de los datos: (1, 64, 64, 1)

# %%
Mi_Foto_Color = autoencder_colorizing.predict(mi_foto_gris_norm)
print('La dimensión de mi foto es de',Mi_Foto_Color.shape)
# Out:
# La dimensión de mi foto es de (1, 64, 64, 3)

# %%
imgs = Mi_Foto_Color
imgs = imgs.reshape((img_rows, img_cols, channels))
plt.figure(figsize=(5,5))
plt.title('imagen Colorizada con el algoritmo')
plt.imshow(imgs)
plt.axis('off')
plt.show()

# %%
imgs = Mi_Foto_Color
imgs = imgs.reshape((img_rows, img_cols, channels))
plt.figure(figsize=(5,5))
plt.title('imagen Colorizada con el algoritmo')
plt.imshow(imgs)
plt.savefig('./test_color.png')
plt.axis('off')
plt.show()

# %%
from google.colab import files
imagesbn = files.upload()
# Out:
#      <input type="file" id="files-5e4beb48-01a8-4901-9034-c324df30348a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e4beb48-01a8-4901-9034-c324df30348a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aaaa.png to aaaa.png

# %%
mi_foto_gris = Image.open('//content/aaaa.png')
mi_foto_gris = mi_foto_gris.convert('L')

# %%
plt.figure(figsize=(5,5))
plt.title('Imagen Original', fontsize = 15)
plt.imshow(mi_foto_gris, cmap='gray')

plt.axis('off')
plt.show()

# %%
mi_foto_gris_norm = (np.array(mi_foto_gris))/255. 

print('La forma fde la imagen reducida es:', mi_foto_gris_norm.shape)
mi_foto_gris_norm = cv2.resize(mi_foto_gris_norm,(64,64)).flatten()
print('Data flatten',mi_foto_gris_norm.shape)
mi_foto_gris_norm = np.array(mi_foto_gris_norm).reshape(1,64,64,1)

print('Nueva forma de los datos:', mi_foto_gris_norm.shape)
# Out:
# La forma fde la imagen reducida es: (877, 860)
# Data flatten (4096,)
# Nueva forma de los datos: (1, 64, 64, 1)

# %%
Mi_Foto_Color = autoencder_colorizing.predict(mi_foto_gris_norm)
print('La dimensión de mi foto es de',Mi_Foto_Color.shape)
# Out:
# La dimensión de mi foto es de (1, 64, 64, 3)

# %%
imgs = Mi_Foto_Color
imgs = imgs.reshape((img_rows, img_cols, channels))
plt.figure(figsize=(5,5))
plt.title('imagen Colorizada con el algoritmo')
plt.imshow(imgs)
plt.axis('off')
plt.show()
